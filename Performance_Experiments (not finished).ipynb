# %% [markdown]
# <a href="https://colab.research.google.com/github/WhiteTeaDragon/SingularValues/blob/main/Performance_Experiments%20(not%20finished).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def Clip_OperatorNorm(conv, inp_shape, clip_to):
  conv_tr = tf.cast(tf.transpose(conv, perm=[2, 3, 0, 1]), tf.complex128)
  conv_shape = conv.get_shape().as_list()
  padding = tf.constant([[0, 0], [0, 0],
                         [0, inp_shape[0] - conv_shape[0]],
                         [0, inp_shape[1] - conv_shape[1]]])
  transform_coeff = tf.fft2d(tf.pad(conv_tr, padding))
  D, U, V = tf.svd(tf.transpose(transform_coeff, perm = [2, 3, 0, 1]))
  norm = tf.reduce_max(D)
  D_clipped = tf.cast(tf.minimum(D, clip_to), tf.complex128)
  clipped_coeff = tf.matmul(U, tf.matmul(tf.linalg.diag(D_clipped),
                                         V, adjoint_b=True))
  clipped_conv_padded = tf.real(tf.ifft2d(
      tf.transpose(clipped_coeff, perm=[2, 3, 0, 1])))
  return tf.slice(tf.transpose(clipped_conv_padded, perm=[2, 3, 0, 1]),
                  [0] * len(conv_shape), conv_shape), norm

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule
    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.
    # Arguments
        epoch (int): The number of epochs
    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder
    Arguments:
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)
    Returns:
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]
    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved
    (downsampled) by a convolutional layer with strides=2, while 
    the number of filters is doubled. Within each stage, 
    the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M
    Arguments:
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    Returns:
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, in [a])')
    # start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            # first layer but not first stack
            if stack > 0 and res_block == 0:  
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            # first layer but not first stack
            if stack > 0 and res_block == 0:
                # linear projection residual shortcut
                # connection to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]
    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or 
    also known as bottleneck layer.
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, 
    the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, 
    while the number of filter maps is
    doubled. Within each stage, the layers have 
    the same number filters and the same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256
    Arguments:
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    Returns:
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 110 in [b])')
    # start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU
    # on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                # first layer and first stage
                if res_block == 0:  
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                # first layer but not first stage
                if res_block == 0:
                    # downsample
                    strides = 2 

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection
                # to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = add([x, y])

        num_filters_in = num_filters_out

    # add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
# from https://github.com/PacktPublishing/Advanced-Deep-Learning-with-Keras/blob/master/chapter2-deep-networks/resnet-cifar10-2.2.1.py
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from tensorflow.keras.layers import Dense, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.layers import AveragePooling2D, Input
from tensorflow.keras.layers import Flatten, add
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import to_categorical
import numpy as np
import os
import math

num_classes = 10
# subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model parameter
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------


# load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# input image dimensions.
input_shape = x_train.shape[1:]

# normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# if subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# convert class vectors to binary class matrices.
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
# training parameters
batch_size = 128
epochs = 250
data_augmentation = True

n = 5

# model version
# orig paper: version = 1 (ResNet v1), 
# improved ResNet: version = 2 (ResNet v2)
version = 1

# computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['acc'])
model.summary()
# Out:
# Learning rate:  0.001
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 32, 32, 16)   448         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 32, 32, 16)   64          conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 32, 32, 16)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 32, 32, 16)   2320        activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 32, 32, 16)   64          conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 32, 32, 16)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 32, 32, 16)   2320        activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 32, 32, 16)   64          conv2d_35[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 32, 32, 16)   0           activation_31[0][0]
#                                                                  batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 32, 32, 16)   0           add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 32, 32, 16)   2320        activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 32, 32, 16)   64          conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 32, 32, 16)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 32, 32, 16)   2320        activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 32, 32, 16)   64          conv2d_37[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 32, 32, 16)   0           activation_33[0][0]
#                                                                  batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 32, 32, 16)   0           add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 32, 32, 16)   2320        activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 32, 32, 16)   64          conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 32, 32, 16)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 32, 32, 16)   2320        activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 32, 32, 16)   64          conv2d_39[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 32, 32, 16)   0           activation_35[0][0]
#                                                                  batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 32, 32, 16)   0           add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 32, 32, 16)   2320        activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 32, 32, 16)   64          conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 32, 32, 16)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 32, 32, 16)   2320        activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 32, 32, 16)   64          conv2d_41[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 32, 32, 16)   0           activation_37[0][0]
#                                                                  batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 32, 32, 16)   0           add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 32, 32, 16)   2320        activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 32, 32, 16)   64          conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 32, 32, 16)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 32, 32, 16)   2320        activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 32, 32, 16)   64          conv2d_43[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 32, 32, 16)   0           activation_39[0][0]
#                                                                  batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 32, 32, 16)   0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 16, 16, 32)   4640        activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 16, 16, 32)   128         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 16, 16, 32)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 16, 16, 32)   9248        activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 16, 16, 32)   544         activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 16, 16, 32)   128         conv2d_45[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 16, 16, 32)   0           conv2d_46[0][0]
#                                                                  batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 16, 16, 32)   0           add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 16, 16, 32)   9248        activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 16, 16, 32)   128         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 16, 16, 32)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 16, 16, 32)   9248        activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 16, 16, 32)   128         conv2d_48[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 16, 16, 32)   0           activation_43[0][0]
#                                                                  batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 16, 16, 32)   0           add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 16, 16, 32)   9248        activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 16, 16, 32)   128         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 16, 16, 32)   0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 16, 16, 32)   9248        activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 16, 16, 32)   128         conv2d_50[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 16, 16, 32)   0           activation_45[0][0]
#                                                                  batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 16, 16, 32)   0           add_22[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 16, 16, 32)   9248        activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 16, 16, 32)   128         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 16, 16, 32)   0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 16, 16, 32)   9248        activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 16, 16, 32)   128         conv2d_52[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 16, 16, 32)   0           activation_47[0][0]
#                                                                  batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 16, 16, 32)   0           add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 16, 16, 32)   9248        activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 16, 16, 32)   128         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 16, 16, 32)   0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 16, 16, 32)   9248        activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 16, 16, 32)   128         conv2d_54[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 16, 16, 32)   0           activation_49[0][0]
#                                                                  batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 16, 16, 32)   0           add_24[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 8, 8, 64)     18496       activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 8, 8, 64)     256         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 8, 8, 64)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 8, 8, 64)     36928       activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 8, 8, 64)     2112        activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 8, 8, 64)     256         conv2d_56[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 8, 8, 64)     0           conv2d_57[0][0]
#                                                                  batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 8, 8, 64)     0           add_25[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 8, 8, 64)     36928       activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 8, 8, 64)     256         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 8, 8, 64)     0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 8, 8, 64)     36928       activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 8, 8, 64)     256         conv2d_59[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 8, 8, 64)     0           activation_53[0][0]
#                                                                  batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 8, 8, 64)     0           add_26[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 8, 8, 64)     36928       activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 8, 8, 64)     256         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 8, 8, 64)     0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 8, 8, 64)     36928       activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 8, 8, 64)     256         conv2d_61[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 8, 8, 64)     0           activation_55[0][0]
#                                                                  batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 8, 8, 64)     0           add_27[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 8, 8, 64)     36928       activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 8, 8, 64)     256         conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 8, 8, 64)     0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 8, 8, 64)     36928       activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 8, 8, 64)     256         conv2d_63[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 8, 8, 64)     0           activation_57[0][0]
#                                                                  batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 8, 8, 64)     0           add_28[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 8, 8, 64)     36928       activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 8, 8, 64)     256         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 8, 8, 64)     0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 8, 8, 64)     36928       activation_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 8, 8, 64)     256         conv2d_65[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 8, 8, 64)     0           activation_59[0][0]
#                                                                  batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 8, 8, 64)     0           add_29[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 64)     0           activation_61[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 64)           0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           650         flatten_1[0][0]
# ==================================================================================================
# Total params: 470,218
# Trainable params: 467,946
# Non-trainable params: 2,272
# __________________________________________________________________________________________________

# %%
# enable this if pydot can be installed
plot_model(model, to_file="%s.png" % model_type, show_shapes=True)
print(model_type)
# Out:
# ResNet32v1

# %%
# prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# %%
# prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
# run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # this will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False)

    # compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    steps_per_epoch =  math.ceil(len(x_train) / batch_size)
    # fit the model on the batches generated by datagen.flow().
    history = model.fit(x=datagen.flow(x_train, y_train, batch_size=batch_size),
              verbose=1,
              epochs=epochs,
              validation_data=(x_test, y_test),
              steps_per_epoch=steps_per_epoch,
              callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# Epoch 1/250
# Learning rate:  0.001
# 391/391 [==============================] - 31s 72ms/step - loss: 1.9608 - acc: 0.3787 - val_loss: 1.8958 - val_acc: 0.4700
#
# Epoch 00001: val_acc improved from -inf to 0.47000, saving model to /content/saved_models/cifar10_ResNet32v1_model.001.h5
# Epoch 2/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 1.3805 - acc: 0.5898 - val_loss: 1.8116 - val_acc: 0.5147
#
# Epoch 00002: val_acc improved from 0.47000 to 0.51470, saving model to /content/saved_models/cifar10_ResNet32v1_model.002.h5
# Epoch 3/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 1.1711 - acc: 0.6657 - val_loss: 1.7829 - val_acc: 0.5593
#
# Epoch 00003: val_acc improved from 0.51470 to 0.55930, saving model to /content/saved_models/cifar10_ResNet32v1_model.003.h5
# Epoch 4/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 1.0369 - acc: 0.7111 - val_loss: 1.2618 - val_acc: 0.6472
#
# Epoch 00004: val_acc improved from 0.55930 to 0.64720, saving model to /content/saved_models/cifar10_ResNet32v1_model.004.h5
# Epoch 5/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.9305 - acc: 0.7480 - val_loss: 0.9955 - val_acc: 0.7305
#
# Epoch 00005: val_acc improved from 0.64720 to 0.73050, saving model to /content/saved_models/cifar10_ResNet32v1_model.005.h5
# Epoch 6/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.8752 - acc: 0.7679 - val_loss: 1.1621 - val_acc: 0.6946
#
# Epoch 00006: val_acc did not improve from 0.73050
# Epoch 7/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.8182 - acc: 0.7889 - val_loss: 1.1895 - val_acc: 0.6753
#
# Epoch 00007: val_acc did not improve from 0.73050
# Epoch 8/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.7694 - acc: 0.8053 - val_loss: 0.9949 - val_acc: 0.7372
#
# Epoch 00008: val_acc improved from 0.73050 to 0.73720, saving model to /content/saved_models/cifar10_ResNet32v1_model.008.h5
# Epoch 9/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.7384 - acc: 0.8135 - val_loss: 0.9702 - val_acc: 0.7475
#
# Epoch 00009: val_acc improved from 0.73720 to 0.74750, saving model to /content/saved_models/cifar10_ResNet32v1_model.009.h5
# Epoch 10/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.7082 - acc: 0.8238 - val_loss: 1.0045 - val_acc: 0.7504
#
# Epoch 00010: val_acc improved from 0.74750 to 0.75040, saving model to /content/saved_models/cifar10_ResNet32v1_model.010.h5
# Epoch 11/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.6786 - acc: 0.8334 - val_loss: 0.8656 - val_acc: 0.7828
#
# Epoch 00011: val_acc improved from 0.75040 to 0.78280, saving model to /content/saved_models/cifar10_ResNet32v1_model.011.h5
# Epoch 12/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.6575 - acc: 0.8408 - val_loss: 0.9140 - val_acc: 0.7708
#
# Epoch 00012: val_acc did not improve from 0.78280
# Epoch 13/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.6330 - acc: 0.8489 - val_loss: 0.9519 - val_acc: 0.7735
#
# Epoch 00013: val_acc did not improve from 0.78280
# Epoch 14/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.6168 - acc: 0.8519 - val_loss: 0.8172 - val_acc: 0.7939
#
# Epoch 00014: val_acc improved from 0.78280 to 0.79390, saving model to /content/saved_models/cifar10_ResNet32v1_model.014.h5
# Epoch 15/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.5990 - acc: 0.8592 - val_loss: 0.7824 - val_acc: 0.8000
#
# Epoch 00015: val_acc improved from 0.79390 to 0.80000, saving model to /content/saved_models/cifar10_ResNet32v1_model.015.h5
# Epoch 16/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.5896 - acc: 0.8614 - val_loss: 0.9016 - val_acc: 0.7781
#
# Epoch 00016: val_acc did not improve from 0.80000
# Epoch 17/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.5768 - acc: 0.8651 - val_loss: 0.9118 - val_acc: 0.7678
#
# Epoch 00017: val_acc did not improve from 0.80000
# Epoch 18/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.5633 - acc: 0.8698 - val_loss: 0.8562 - val_acc: 0.7983
#
# Epoch 00018: val_acc did not improve from 0.80000
# Epoch 19/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.5667 - acc: 0.8701 - val_loss: 0.6936 - val_acc: 0.8246
#
# Epoch 00019: val_acc improved from 0.80000 to 0.82460, saving model to /content/saved_models/cifar10_ResNet32v1_model.019.h5
# Epoch 20/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.5356 - acc: 0.8823 - val_loss: 0.8178 - val_acc: 0.7944
#
# Epoch 00020: val_acc did not improve from 0.82460
# Epoch 21/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.5315 - acc: 0.8826 - val_loss: 0.8436 - val_acc: 0.7951
#
# Epoch 00021: val_acc did not improve from 0.82460
# Epoch 22/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.5231 - acc: 0.8839 - val_loss: 1.4015 - val_acc: 0.6824
#
# Epoch 00022: val_acc did not improve from 0.82460
# Epoch 23/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.5116 - acc: 0.8862 - val_loss: 0.7574 - val_acc: 0.8248
#
# Epoch 00023: val_acc improved from 0.82460 to 0.82480, saving model to /content/saved_models/cifar10_ResNet32v1_model.023.h5
# Epoch 24/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.5018 - acc: 0.8916 - val_loss: 0.9234 - val_acc: 0.7812
#
# Epoch 00024: val_acc did not improve from 0.82480
# Epoch 25/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.4960 - acc: 0.8931 - val_loss: 0.7251 - val_acc: 0.8239
#
# Epoch 00025: val_acc did not improve from 0.82480
# Epoch 26/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.4940 - acc: 0.8936 - val_loss: 0.6356 - val_acc: 0.8548
#
# Epoch 00026: val_acc improved from 0.82480 to 0.85480, saving model to /content/saved_models/cifar10_ResNet32v1_model.026.h5
# Epoch 27/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.4817 - acc: 0.8991 - val_loss: 1.0906 - val_acc: 0.7626
#
# Epoch 00027: val_acc did not improve from 0.85480
# Epoch 28/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.4814 - acc: 0.8986 - val_loss: 0.8631 - val_acc: 0.8130
#
# Epoch 00028: val_acc did not improve from 0.85480
# Epoch 29/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.4708 - acc: 0.9035 - val_loss: 0.7406 - val_acc: 0.8181
#
# Epoch 00029: val_acc did not improve from 0.85480
# Epoch 30/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.4683 - acc: 0.9019 - val_loss: 0.6281 - val_acc: 0.8559
#
# Epoch 00030: val_acc improved from 0.85480 to 0.85590, saving model to /content/saved_models/cifar10_ResNet32v1_model.030.h5
# Epoch 31/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.4623 - acc: 0.9060 - val_loss: 0.9163 - val_acc: 0.7855
#
# Epoch 00031: val_acc did not improve from 0.85590
# Epoch 32/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.4558 - acc: 0.9074 - val_loss: 0.8234 - val_acc: 0.8021
#
# Epoch 00032: val_acc did not improve from 0.85590
# Epoch 33/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.4462 - acc: 0.9087 - val_loss: 0.8350 - val_acc: 0.8066
#
# Epoch 00033: val_acc did not improve from 0.85590
# Epoch 34/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.4495 - acc: 0.9079 - val_loss: 0.7750 - val_acc: 0.8207
#
# Epoch 00034: val_acc did not improve from 0.85590
# Epoch 35/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.4456 - acc: 0.9110 - val_loss: 0.8401 - val_acc: 0.8124
#
# Epoch 00035: val_acc did not improve from 0.85590
# Epoch 36/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.4380 - acc: 0.9126 - val_loss: 0.9706 - val_acc: 0.7665
#
# Epoch 00036: val_acc did not improve from 0.85590
# Epoch 37/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.4397 - acc: 0.9121 - val_loss: 0.7860 - val_acc: 0.8277
#
# Epoch 00037: val_acc did not improve from 0.85590
# Epoch 38/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.4398 - acc: 0.9118 - val_loss: 0.8714 - val_acc: 0.8031
#
# Epoch 00038: val_acc did not improve from 0.85590
# Epoch 39/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.4306 - acc: 0.9167 - val_loss: 0.6780 - val_acc: 0.8453
#
# Epoch 00039: val_acc did not improve from 0.85590
# Epoch 40/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.4223 - acc: 0.9229 - val_loss: 0.8335 - val_acc: 0.8169
#
# Epoch 00040: val_acc did not improve from 0.85590
# Epoch 41/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.4319 - acc: 0.9153 - val_loss: 0.6810 - val_acc: 0.8489
#
# Epoch 00041: val_acc did not improve from 0.85590
# Epoch 42/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.4172 - acc: 0.9216 - val_loss: 0.6756 - val_acc: 0.8465
#
# Epoch 00042: val_acc did not improve from 0.85590
# Epoch 43/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.4139 - acc: 0.9219 - val_loss: 1.2944 - val_acc: 0.7155
#
# Epoch 00043: val_acc did not improve from 0.85590
# Epoch 44/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.4212 - acc: 0.9189 - val_loss: 0.8347 - val_acc: 0.8111
#
# Epoch 00044: val_acc did not improve from 0.85590
# Epoch 45/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.4229 - acc: 0.9162 - val_loss: 0.9796 - val_acc: 0.7955
#
# Epoch 00045: val_acc did not improve from 0.85590
# Epoch 46/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.4088 - acc: 0.9236 - val_loss: 0.6633 - val_acc: 0.8529
#
# Epoch 00046: val_acc did not improve from 0.85590
# Epoch 47/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.4185 - acc: 0.9190 - val_loss: 0.7517 - val_acc: 0.8320
#
# Epoch 00047: val_acc did not improve from 0.85590
# Epoch 48/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.4090 - acc: 0.9230 - val_loss: 1.1708 - val_acc: 0.7594
#
# Epoch 00048: val_acc did not improve from 0.85590
# Epoch 49/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.4103 - acc: 0.9236 - val_loss: 0.9720 - val_acc: 0.8054
#
# Epoch 00049: val_acc did not improve from 0.85590
# Epoch 50/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.4016 - acc: 0.9287 - val_loss: 0.5951 - val_acc: 0.8696
#
# Epoch 00050: val_acc improved from 0.85590 to 0.86960, saving model to /content/saved_models/cifar10_ResNet32v1_model.050.h5
# Epoch 51/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.4011 - acc: 0.9276 - val_loss: 0.6827 - val_acc: 0.8506
#
# Epoch 00051: val_acc did not improve from 0.86960
# Epoch 52/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.4030 - acc: 0.9264 - val_loss: 0.6725 - val_acc: 0.8535
#
# Epoch 00052: val_acc did not improve from 0.86960
# Epoch 53/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.3978 - acc: 0.9275 - val_loss: 1.1198 - val_acc: 0.7540
#
# Epoch 00053: val_acc did not improve from 0.86960
# Epoch 54/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.3941 - acc: 0.9288 - val_loss: 0.8066 - val_acc: 0.8294
#
# Epoch 00054: val_acc did not improve from 0.86960
# Epoch 55/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.4023 - acc: 0.9265 - val_loss: 0.7313 - val_acc: 0.8388
#
# Epoch 00055: val_acc did not improve from 0.86960
# Epoch 56/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.3905 - acc: 0.9303 - val_loss: 0.8994 - val_acc: 0.8024
#
# Epoch 00056: val_acc did not improve from 0.86960
# Epoch 57/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.3847 - acc: 0.9322 - val_loss: 0.9016 - val_acc: 0.8013
#
# Epoch 00057: val_acc did not improve from 0.86960
# Epoch 58/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.3908 - acc: 0.9305 - val_loss: 0.6868 - val_acc: 0.8403
#
# Epoch 00058: val_acc did not improve from 0.86960
# Epoch 59/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.3883 - acc: 0.9306 - val_loss: 1.0048 - val_acc: 0.7870
#
# Epoch 00059: val_acc did not improve from 0.86960
# Epoch 60/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.3871 - acc: 0.9331 - val_loss: 0.6921 - val_acc: 0.8464
#
# Epoch 00060: val_acc did not improve from 0.86960
# Epoch 61/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.3861 - acc: 0.9317 - val_loss: 0.8268 - val_acc: 0.8238
#
# Epoch 00061: val_acc did not improve from 0.86960
# Epoch 62/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.3852 - acc: 0.9309 - val_loss: 0.7373 - val_acc: 0.8386
#
# Epoch 00062: val_acc did not improve from 0.86960
# Epoch 63/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.3804 - acc: 0.9359 - val_loss: 0.8659 - val_acc: 0.8066
#
# Epoch 00063: val_acc did not improve from 0.86960
# Epoch 64/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.3850 - acc: 0.9323 - val_loss: 0.7123 - val_acc: 0.8450
#
# Epoch 00064: val_acc did not improve from 0.86960
# Epoch 65/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.3756 - acc: 0.9362 - val_loss: 0.7323 - val_acc: 0.8462
#
# Epoch 00065: val_acc did not improve from 0.86960
# Epoch 66/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 69ms/step - loss: 0.3789 - acc: 0.9336 - val_loss: 0.6553 - val_acc: 0.8573
#
# Epoch 00066: val_acc did not improve from 0.86960
# Epoch 67/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.3867 - acc: 0.9328 - val_loss: 0.8415 - val_acc: 0.8335
#
# Epoch 00067: val_acc did not improve from 0.86960
# Epoch 68/250
# Learning rate:  0.001
# 391/391 [==============================] - 28s 70ms/step - loss: 0.3765 - acc: 0.9367 - val_loss: 0.7167 - val_acc: 0.8426
#
# Epoch 00068: val_acc did not improve from 0.86960
# Epoch 69/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.3748 - acc: 0.9359 - val_loss: 1.5928 - val_acc: 0.7058
#
# Epoch 00069: val_acc did not improve from 0.86960
# Epoch 70/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.3728 - acc: 0.9368 - val_loss: 0.7509 - val_acc: 0.8432
#
# Epoch 00070: val_acc did not improve from 0.86960
# Epoch 71/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.3757 - acc: 0.9361 - val_loss: 0.8103 - val_acc: 0.8215
#
# Epoch 00071: val_acc did not improve from 0.86960
# Epoch 72/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.3809 - acc: 0.9349 - val_loss: 0.7803 - val_acc: 0.8321
#
# Epoch 00072: val_acc did not improve from 0.86960
# Epoch 73/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.3723 - acc: 0.9366 - val_loss: 0.6504 - val_acc: 0.8531
#
# Epoch 00073: val_acc did not improve from 0.86960
# Epoch 74/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.3731 - acc: 0.9376 - val_loss: 0.7527 - val_acc: 0.8410
#
# Epoch 00074: val_acc did not improve from 0.86960
# Epoch 75/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.3727 - acc: 0.9372 - val_loss: 0.6329 - val_acc: 0.8640
#
# Epoch 00075: val_acc did not improve from 0.86960
# Epoch 76/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.3648 - acc: 0.9406 - val_loss: 0.8140 - val_acc: 0.8279
#
# Epoch 00076: val_acc did not improve from 0.86960
# Epoch 77/250
# Learning rate:  0.001
# 391/391 [==============================] - 28s 70ms/step - loss: 0.3695 - acc: 0.9380 - val_loss: 0.8345 - val_acc: 0.8209
#
# Epoch 00077: val_acc did not improve from 0.86960
# Epoch 78/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.3670 - acc: 0.9386 - val_loss: 0.7208 - val_acc: 0.8499
#
# Epoch 00078: val_acc did not improve from 0.86960
# Epoch 79/250
# Learning rate:  0.001
# 391/391 [==============================] - 28s 70ms/step - loss: 0.3744 - acc: 0.9378 - val_loss: 0.6998 - val_acc: 0.8529
#
# Epoch 00079: val_acc did not improve from 0.86960
# Epoch 80/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.3656 - acc: 0.9384 - val_loss: 0.6020 - val_acc: 0.8717
#
# Epoch 00080: val_acc improved from 0.86960 to 0.87170, saving model to /content/saved_models/cifar10_ResNet32v1_model.080.h5
# Epoch 81/250
# Learning rate:  0.001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.3678 - acc: 0.9376 - val_loss: 0.6675 - val_acc: 0.8561
#
# Epoch 00081: val_acc did not improve from 0.87170
# Epoch 82/250
# Learning rate:  0.0001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.3208 - acc: 0.9547 - val_loss: 0.5023 - val_acc: 0.9063
#
# Epoch 00082: val_acc improved from 0.87170 to 0.90630, saving model to /content/saved_models/cifar10_ResNet32v1_model.082.h5
# Epoch 83/250
# Learning rate:  0.0001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.2843 - acc: 0.9684 - val_loss: 0.5019 - val_acc: 0.9069
#
# Epoch 00083: val_acc improved from 0.90630 to 0.90690, saving model to /content/saved_models/cifar10_ResNet32v1_model.083.h5
# Epoch 84/250
# Learning rate:  0.0001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.2684 - acc: 0.9730 - val_loss: 0.4943 - val_acc: 0.9097
#
# Epoch 00084: val_acc improved from 0.90690 to 0.90970, saving model to /content/saved_models/cifar10_ResNet32v1_model.084.h5
# Epoch 85/250
# Learning rate:  0.0001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.2575 - acc: 0.9770 - val_loss: 0.5021 - val_acc: 0.9117
#
# Epoch 00085: val_acc improved from 0.90970 to 0.91170, saving model to /content/saved_models/cifar10_ResNet32v1_model.085.h5
# Epoch 86/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.2542 - acc: 0.9769 - val_loss: 0.4984 - val_acc: 0.9094
#
# Epoch 00086: val_acc did not improve from 0.91170
# Epoch 87/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.2456 - acc: 0.9792 - val_loss: 0.5123 - val_acc: 0.9064
#
# Epoch 00087: val_acc did not improve from 0.91170
# Epoch 88/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 70ms/step - loss: 0.2424 - acc: 0.9800 - val_loss: 0.4997 - val_acc: 0.9097
#
# Epoch 00088: val_acc did not improve from 0.91170
# Epoch 89/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.2388 - acc: 0.9809 - val_loss: 0.5073 - val_acc: 0.9109
#
# Epoch 00089: val_acc did not improve from 0.91170
# Epoch 90/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.2301 - acc: 0.9842 - val_loss: 0.5081 - val_acc: 0.9114
#
# Epoch 00090: val_acc did not improve from 0.91170
# Epoch 91/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.2311 - acc: 0.9822 - val_loss: 0.5186 - val_acc: 0.9111
#
# Epoch 00091: val_acc did not improve from 0.91170
# Epoch 92/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.2250 - acc: 0.9837 - val_loss: 0.5144 - val_acc: 0.9107
#
# Epoch 00092: val_acc did not improve from 0.91170
# Epoch 93/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.2200 - acc: 0.9849 - val_loss: 0.5202 - val_acc: 0.9087
#
# Epoch 00093: val_acc did not improve from 0.91170
# Epoch 94/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.2177 - acc: 0.9858 - val_loss: 0.5237 - val_acc: 0.9087
#
# Epoch 00094: val_acc did not improve from 0.91170
# Epoch 95/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.2149 - acc: 0.9849 - val_loss: 0.5209 - val_acc: 0.9102
#
# Epoch 00095: val_acc did not improve from 0.91170
# Epoch 96/250
# Learning rate:  0.0001
# 391/391 [==============================] - 27s 70ms/step - loss: 0.2111 - acc: 0.9859 - val_loss: 0.5299 - val_acc: 0.9066
#
# Epoch 00096: val_acc did not improve from 0.91170
# Epoch 97/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.2053 - acc: 0.9875 - val_loss: 0.5292 - val_acc: 0.9093
#
# Epoch 00097: val_acc did not improve from 0.91170
# Epoch 98/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.2024 - acc: 0.9894 - val_loss: 0.5154 - val_acc: 0.9123
#
# Epoch 00098: val_acc improved from 0.91170 to 0.91230, saving model to /content/saved_models/cifar10_ResNet32v1_model.098.h5
# Epoch 99/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 70ms/step - loss: 0.2031 - acc: 0.9876 - val_loss: 0.5360 - val_acc: 0.9067
#
# Epoch 00099: val_acc did not improve from 0.91230
# Epoch 100/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1983 - acc: 0.9889 - val_loss: 0.5191 - val_acc: 0.9115
#
# Epoch 00100: val_acc did not improve from 0.91230
# Epoch 101/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 70ms/step - loss: 0.1973 - acc: 0.9880 - val_loss: 0.5537 - val_acc: 0.9073
#
# Epoch 00101: val_acc did not improve from 0.91230
# Epoch 102/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1962 - acc: 0.9880 - val_loss: 0.5334 - val_acc: 0.9097
#
# Epoch 00102: val_acc did not improve from 0.91230
# Epoch 103/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1917 - acc: 0.9897 - val_loss: 0.5385 - val_acc: 0.9086
#
# Epoch 00103: val_acc did not improve from 0.91230
# Epoch 104/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1897 - acc: 0.9901 - val_loss: 0.5301 - val_acc: 0.9110
#
# Epoch 00104: val_acc did not improve from 0.91230
# Epoch 105/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 70ms/step - loss: 0.1912 - acc: 0.9878 - val_loss: 0.5433 - val_acc: 0.9075
#
# Epoch 00105: val_acc did not improve from 0.91230
# Epoch 106/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1875 - acc: 0.9893 - val_loss: 0.5596 - val_acc: 0.9070
#
# Epoch 00106: val_acc did not improve from 0.91230
# Epoch 107/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1866 - acc: 0.9885 - val_loss: 0.5259 - val_acc: 0.9099
#
# Epoch 00107: val_acc did not improve from 0.91230
# Epoch 108/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1809 - acc: 0.9912 - val_loss: 0.5338 - val_acc: 0.9097
#
# Epoch 00108: val_acc did not improve from 0.91230
# Epoch 109/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1780 - acc: 0.9916 - val_loss: 0.5349 - val_acc: 0.9126
#
# Epoch 00109: val_acc improved from 0.91230 to 0.91260, saving model to /content/saved_models/cifar10_ResNet32v1_model.109.h5
# Epoch 110/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1776 - acc: 0.9913 - val_loss: 0.5303 - val_acc: 0.9106
#
# Epoch 00110: val_acc did not improve from 0.91260
# Epoch 111/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1766 - acc: 0.9913 - val_loss: 0.5339 - val_acc: 0.9116
#
# Epoch 00111: val_acc did not improve from 0.91260
# Epoch 112/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1757 - acc: 0.9915 - val_loss: 0.5296 - val_acc: 0.9103
#
# Epoch 00112: val_acc did not improve from 0.91260
# Epoch 113/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 72ms/step - loss: 0.1750 - acc: 0.9910 - val_loss: 0.5585 - val_acc: 0.9066
#
# Epoch 00113: val_acc did not improve from 0.91260
# Epoch 114/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1723 - acc: 0.9915 - val_loss: 0.5374 - val_acc: 0.9115
#
# Epoch 00114: val_acc did not improve from 0.91260
# Epoch 115/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1698 - acc: 0.9919 - val_loss: 0.5425 - val_acc: 0.9072
#
# Epoch 00115: val_acc did not improve from 0.91260
# Epoch 116/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1685 - acc: 0.9922 - val_loss: 0.5382 - val_acc: 0.9119
#
# Epoch 00116: val_acc did not improve from 0.91260
# Epoch 117/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1688 - acc: 0.9916 - val_loss: 0.5732 - val_acc: 0.9055
#
# Epoch 00117: val_acc did not improve from 0.91260
# Epoch 118/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1644 - acc: 0.9927 - val_loss: 0.5519 - val_acc: 0.9094
#
# Epoch 00118: val_acc did not improve from 0.91260
# Epoch 119/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1655 - acc: 0.9918 - val_loss: 0.5610 - val_acc: 0.9070
#
# Epoch 00119: val_acc did not improve from 0.91260
# Epoch 120/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 70ms/step - loss: 0.1647 - acc: 0.9923 - val_loss: 0.5561 - val_acc: 0.9082
#
# Epoch 00120: val_acc did not improve from 0.91260
# Epoch 121/250
# Learning rate:  0.0001
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1618 - acc: 0.9926 - val_loss: 0.5677 - val_acc: 0.9071
#
# Epoch 00121: val_acc did not improve from 0.91260
# Epoch 122/250
# Learning rate:  1e-05
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1590 - acc: 0.9933 - val_loss: 0.5297 - val_acc: 0.9112
#
# Epoch 00122: val_acc did not improve from 0.91260
# Epoch 123/250
# Learning rate:  1e-05
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1571 - acc: 0.9937 - val_loss: 0.5287 - val_acc: 0.9127
#
# Epoch 00123: val_acc improved from 0.91260 to 0.91270, saving model to /content/saved_models/cifar10_ResNet32v1_model.123.h5
# Epoch 124/250
# Learning rate:  1e-05
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1554 - acc: 0.9946 - val_loss: 0.5289 - val_acc: 0.9133
#
# Epoch 00124: val_acc improved from 0.91270 to 0.91330, saving model to /content/saved_models/cifar10_ResNet32v1_model.124.h5
# Epoch 125/250
# Learning rate:  1e-05
# 391/391 [==============================] - 28s 70ms/step - loss: 0.1552 - acc: 0.9946 - val_loss: 0.5275 - val_acc: 0.9133
#
# Epoch 00125: val_acc did not improve from 0.91330
# Epoch 126/250
# Learning rate:  1e-05
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1568 - acc: 0.9941 - val_loss: 0.5286 - val_acc: 0.9134
#
# Epoch 00126: val_acc improved from 0.91330 to 0.91340, saving model to /content/saved_models/cifar10_ResNet32v1_model.126.h5
# Epoch 127/250
# Learning rate:  1e-05
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1544 - acc: 0.9948 - val_loss: 0.5282 - val_acc: 0.9143
#
# Epoch 00127: val_acc improved from 0.91340 to 0.91430, saving model to /content/saved_models/cifar10_ResNet32v1_model.127.h5
# Epoch 128/250
# Learning rate:  1e-05
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1543 - acc: 0.9948 - val_loss: 0.5261 - val_acc: 0.9151
#
# Epoch 00128: val_acc improved from 0.91430 to 0.91510, saving model to /content/saved_models/cifar10_ResNet32v1_model.128.h5
# Epoch 129/250
# Learning rate:  1e-05
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1540 - acc: 0.9950 - val_loss: 0.5245 - val_acc: 0.9141
#
# Epoch 00129: val_acc did not improve from 0.91510
# Epoch 130/250
# Learning rate:  1e-05
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1524 - acc: 0.9955 - val_loss: 0.5280 - val_acc: 0.9146
#
# Epoch 00130: val_acc did not improve from 0.91510
# Epoch 131/250
# Learning rate:  1e-05
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1525 - acc: 0.9952 - val_loss: 0.5291 - val_acc: 0.9135
#
# Epoch 00131: val_acc did not improve from 0.91510
# Epoch 132/250
# Learning rate:  1e-05
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1512 - acc: 0.9961 - val_loss: 0.5304 - val_acc: 0.9142
#
# Epoch 00132: val_acc did not improve from 0.91510
# Epoch 133/250
# Learning rate:  1e-05
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1519 - acc: 0.9953 - val_loss: 0.5327 - val_acc: 0.9124
#
# Epoch 00133: val_acc did not improve from 0.91510
# Epoch 134/250
# Learning rate:  1e-05
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1525 - acc: 0.9956 - val_loss: 0.5283 - val_acc: 0.9140
#
# Epoch 00134: val_acc did not improve from 0.91510
# Epoch 135/250
# Learning rate:  1e-05
# 391/391 [==============================] - 28s 72ms/step - loss: 0.1515 - acc: 0.9958 - val_loss: 0.5310 - val_acc: 0.9145
#
# Epoch 00135: val_acc did not improve from 0.91510
# Epoch 136/250
# Learning rate:  1e-05
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1491 - acc: 0.9964 - val_loss: 0.5293 - val_acc: 0.9140
#
# Epoch 00136: val_acc did not improve from 0.91510
# Epoch 137/250
# Learning rate:  1e-05
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1504 - acc: 0.9959 - val_loss: 0.5305 - val_acc: 0.9143
#
# Epoch 00137: val_acc did not improve from 0.91510
# Epoch 138/250
# Learning rate:  1e-05
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1523 - acc: 0.9950 - val_loss: 0.5340 - val_acc: 0.9135
#
# Epoch 00138: val_acc did not improve from 0.91510
# Epoch 139/250
# Learning rate:  1e-05
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1495 - acc: 0.9962 - val_loss: 0.5327 - val_acc: 0.9142
#
# Epoch 00139: val_acc did not improve from 0.91510
# Epoch 140/250
# Learning rate:  1e-05
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1489 - acc: 0.9961 - val_loss: 0.5326 - val_acc: 0.9143
#
# Epoch 00140: val_acc did not improve from 0.91510
# Epoch 141/250
# Learning rate:  1e-05
# 391/391 [==============================] - 27s 70ms/step - loss: 0.1498 - acc: 0.9956 - val_loss: 0.5332 - val_acc: 0.9147
#
# Epoch 00141: val_acc did not improve from 0.91510
# Epoch 142/250
# Learning rate:  1e-05
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1497 - acc: 0.9959 - val_loss: 0.5332 - val_acc: 0.9140
#
# Epoch 00142: val_acc did not improve from 0.91510
# Epoch 143/250
# Learning rate:  1e-05
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1485 - acc: 0.9961 - val_loss: 0.5327 - val_acc: 0.9148
#
# Epoch 00143: val_acc did not improve from 0.91510
# Epoch 144/250
# Learning rate:  1e-05
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1485 - acc: 0.9962 - val_loss: 0.5333 - val_acc: 0.9142
#
# Epoch 00144: val_acc did not improve from 0.91510
# Epoch 145/250
# Learning rate:  1e-05
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1489 - acc: 0.9962 - val_loss: 0.5352 - val_acc: 0.9138
#
# Epoch 00145: val_acc did not improve from 0.91510
# Epoch 146/250
# Learning rate:  1e-05
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1466 - acc: 0.9969 - val_loss: 0.5341 - val_acc: 0.9152
#
# Epoch 00146: val_acc improved from 0.91510 to 0.91520, saving model to /content/saved_models/cifar10_ResNet32v1_model.146.h5
# Epoch 147/250
# Learning rate:  1e-05
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1478 - acc: 0.9963 - val_loss: 0.5388 - val_acc: 0.9131
#
# Epoch 00147: val_acc did not improve from 0.91520
# Epoch 148/250
# Learning rate:  1e-05
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1481 - acc: 0.9961 - val_loss: 0.5343 - val_acc: 0.9136
#
# Epoch 00148: val_acc did not improve from 0.91520
# Epoch 149/250
# Learning rate:  1e-05
# 391/391 [==============================] - 27s 70ms/step - loss: 0.1471 - acc: 0.9965 - val_loss: 0.5345 - val_acc: 0.9134
#
# Epoch 00149: val_acc did not improve from 0.91520
# Epoch 150/250
# Learning rate:  1e-05
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1470 - acc: 0.9967 - val_loss: 0.5335 - val_acc: 0.9133
#
# Epoch 00150: val_acc did not improve from 0.91520
# Epoch 151/250
# Learning rate:  1e-05
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1474 - acc: 0.9964 - val_loss: 0.5343 - val_acc: 0.9134
#
# Epoch 00151: val_acc did not improve from 0.91520
# Epoch 152/250
# Learning rate:  1e-05
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1470 - acc: 0.9965 - val_loss: 0.5337 - val_acc: 0.9136
#
# Epoch 00152: val_acc did not improve from 0.91520
# Epoch 153/250
# Learning rate:  1e-05
# 391/391 [==============================] - 27s 70ms/step - loss: 0.1468 - acc: 0.9964 - val_loss: 0.5356 - val_acc: 0.9145
#
# Epoch 00153: val_acc did not improve from 0.91520
# Epoch 154/250
# Learning rate:  1e-05
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1456 - acc: 0.9964 - val_loss: 0.5345 - val_acc: 0.9131
#
# Epoch 00154: val_acc did not improve from 0.91520
# Epoch 155/250
# Learning rate:  1e-05
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1471 - acc: 0.9961 - val_loss: 0.5370 - val_acc: 0.9135
#
# Epoch 00155: val_acc did not improve from 0.91520
# Epoch 156/250
# Learning rate:  1e-05
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1463 - acc: 0.9962 - val_loss: 0.5364 - val_acc: 0.9133
#
# Epoch 00156: val_acc did not improve from 0.91520
# Epoch 157/250
# Learning rate:  1e-05
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1458 - acc: 0.9964 - val_loss: 0.5375 - val_acc: 0.9135
#
# Epoch 00157: val_acc did not improve from 0.91520
# Epoch 158/250
# Learning rate:  1e-05
# 391/391 [==============================] - 27s 70ms/step - loss: 0.1452 - acc: 0.9969 - val_loss: 0.5364 - val_acc: 0.9139
#
# Epoch 00158: val_acc did not improve from 0.91520
# Epoch 159/250
# Learning rate:  1e-05
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1446 - acc: 0.9970 - val_loss: 0.5370 - val_acc: 0.9139
#
# Epoch 00159: val_acc did not improve from 0.91520
# Epoch 160/250
# Learning rate:  1e-05
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1456 - acc: 0.9964 - val_loss: 0.5409 - val_acc: 0.9138
#
# Epoch 00160: val_acc did not improve from 0.91520
# Epoch 161/250
# Learning rate:  1e-05
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1462 - acc: 0.9962 - val_loss: 0.5413 - val_acc: 0.9139
#
# Epoch 00161: val_acc did not improve from 0.91520
# Epoch 162/250
# Learning rate:  1e-06
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1436 - acc: 0.9972 - val_loss: 0.5405 - val_acc: 0.9141
#
# Epoch 00162: val_acc did not improve from 0.91520
# Epoch 163/250
# Learning rate:  1e-06
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1458 - acc: 0.9960 - val_loss: 0.5398 - val_acc: 0.9137
#
# Epoch 00163: val_acc did not improve from 0.91520
# Epoch 164/250
# Learning rate:  1e-06
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1442 - acc: 0.9970 - val_loss: 0.5390 - val_acc: 0.9142
#
# Epoch 00164: val_acc did not improve from 0.91520
# Epoch 165/250
# Learning rate:  1e-06
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1440 - acc: 0.9971 - val_loss: 0.5390 - val_acc: 0.9143
#
# Epoch 00165: val_acc did not improve from 0.91520
# Epoch 166/250
# Learning rate:  1e-06
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1437 - acc: 0.9970 - val_loss: 0.5395 - val_acc: 0.9143
#
# Epoch 00166: val_acc did not improve from 0.91520
# Epoch 167/250
# Learning rate:  1e-06
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1437 - acc: 0.9966 - val_loss: 0.5396 - val_acc: 0.9148
#
# Epoch 00167: val_acc did not improve from 0.91520
# Epoch 168/250
# Learning rate:  1e-06
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1449 - acc: 0.9961 - val_loss: 0.5396 - val_acc: 0.9142
#
# Epoch 00168: val_acc did not improve from 0.91520
# Epoch 169/250
# Learning rate:  1e-06
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1450 - acc: 0.9965 - val_loss: 0.5400 - val_acc: 0.9145
#
# Epoch 00169: val_acc did not improve from 0.91520
# Epoch 170/250
# Learning rate:  1e-06
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1445 - acc: 0.9964 - val_loss: 0.5409 - val_acc: 0.9138
#
# Epoch 00170: val_acc did not improve from 0.91520
# Epoch 171/250
# Learning rate:  1e-06
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1443 - acc: 0.9969 - val_loss: 0.5408 - val_acc: 0.9142
#
# Epoch 00171: val_acc did not improve from 0.91520
# Epoch 172/250
# Learning rate:  1e-06
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1439 - acc: 0.9968 - val_loss: 0.5388 - val_acc: 0.9140
#
# Epoch 00172: val_acc did not improve from 0.91520
# Epoch 173/250
# Learning rate:  1e-06
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1443 - acc: 0.9968 - val_loss: 0.5396 - val_acc: 0.9145
#
# Epoch 00173: val_acc did not improve from 0.91520
# Epoch 174/250
# Learning rate:  1e-06
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1442 - acc: 0.9964 - val_loss: 0.5408 - val_acc: 0.9139
#
# Epoch 00174: val_acc did not improve from 0.91520
# Epoch 175/250
# Learning rate:  1e-06
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1436 - acc: 0.9969 - val_loss: 0.5398 - val_acc: 0.9140
#
# Epoch 00175: val_acc did not improve from 0.91520
# Epoch 176/250
# Learning rate:  1e-06
# 391/391 [==============================] - 27s 70ms/step - loss: 0.1439 - acc: 0.9971 - val_loss: 0.5396 - val_acc: 0.9133
#
# Epoch 00176: val_acc did not improve from 0.91520
# Epoch 177/250
# Learning rate:  1e-06
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1438 - acc: 0.9967 - val_loss: 0.5408 - val_acc: 0.9140
#
# Epoch 00177: val_acc did not improve from 0.91520
# Epoch 178/250
# Learning rate:  1e-06
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1455 - acc: 0.9961 - val_loss: 0.5397 - val_acc: 0.9145
#
# Epoch 00178: val_acc did not improve from 0.91520
# Epoch 179/250
# Learning rate:  1e-06
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1432 - acc: 0.9972 - val_loss: 0.5393 - val_acc: 0.9141
#
# Epoch 00179: val_acc did not improve from 0.91520
# Epoch 180/250
# Learning rate:  1e-06
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1441 - acc: 0.9967 - val_loss: 0.5388 - val_acc: 0.9142
#
# Epoch 00180: val_acc did not improve from 0.91520
# Epoch 181/250
# Learning rate:  1e-06
# 391/391 [==============================] - 27s 70ms/step - loss: 0.1429 - acc: 0.9973 - val_loss: 0.5379 - val_acc: 0.9145
#
# Epoch 00181: val_acc did not improve from 0.91520
# Epoch 182/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1433 - acc: 0.9967 - val_loss: 0.5393 - val_acc: 0.9139
#
# Epoch 00182: val_acc did not improve from 0.91520
# Epoch 183/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1437 - acc: 0.9966 - val_loss: 0.5384 - val_acc: 0.9144
#
# Epoch 00183: val_acc did not improve from 0.91520
# Epoch 184/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1431 - acc: 0.9969 - val_loss: 0.5387 - val_acc: 0.9141
#
# Epoch 00184: val_acc did not improve from 0.91520
# Epoch 185/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1429 - acc: 0.9975 - val_loss: 0.5376 - val_acc: 0.9143
#
# Epoch 00185: val_acc did not improve from 0.91520
# Epoch 186/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1430 - acc: 0.9971 - val_loss: 0.5390 - val_acc: 0.9142
#
# Epoch 00186: val_acc did not improve from 0.91520
# Epoch 187/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1434 - acc: 0.9972 - val_loss: 0.5383 - val_acc: 0.9147
#
# Epoch 00187: val_acc did not improve from 0.91520
# Epoch 188/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1450 - acc: 0.9961 - val_loss: 0.5392 - val_acc: 0.9144
#
# Epoch 00188: val_acc did not improve from 0.91520
# Epoch 189/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1439 - acc: 0.9967 - val_loss: 0.5381 - val_acc: 0.9149
#
# Epoch 00189: val_acc did not improve from 0.91520
# Epoch 190/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1425 - acc: 0.9973 - val_loss: 0.5401 - val_acc: 0.9142
#
# Epoch 00190: val_acc did not improve from 0.91520
# Epoch 191/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1434 - acc: 0.9973 - val_loss: 0.5391 - val_acc: 0.9148
#
# Epoch 00191: val_acc did not improve from 0.91520
# Epoch 192/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1435 - acc: 0.9969 - val_loss: 0.5389 - val_acc: 0.9144
#
# Epoch 00192: val_acc did not improve from 0.91520
# Epoch 193/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1431 - acc: 0.9971 - val_loss: 0.5401 - val_acc: 0.9136
#
# Epoch 00193: val_acc did not improve from 0.91520
# Epoch 194/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1438 - acc: 0.9968 - val_loss: 0.5387 - val_acc: 0.9143
#
# Epoch 00194: val_acc did not improve from 0.91520
# Epoch 195/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1429 - acc: 0.9969 - val_loss: 0.5394 - val_acc: 0.9137
#
# Epoch 00195: val_acc did not improve from 0.91520
# Epoch 196/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1437 - acc: 0.9968 - val_loss: 0.5400 - val_acc: 0.9140
#
# Epoch 00196: val_acc did not improve from 0.91520
# Epoch 197/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1436 - acc: 0.9971 - val_loss: 0.5378 - val_acc: 0.9141
#
# Epoch 00197: val_acc did not improve from 0.91520
# Epoch 198/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1434 - acc: 0.9967 - val_loss: 0.5394 - val_acc: 0.9142
#
# Epoch 00198: val_acc did not improve from 0.91520
# Epoch 199/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1440 - acc: 0.9967 - val_loss: 0.5405 - val_acc: 0.9137
#
# Epoch 00199: val_acc did not improve from 0.91520
# Epoch 200/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1427 - acc: 0.9973 - val_loss: 0.5392 - val_acc: 0.9147
#
# Epoch 00200: val_acc did not improve from 0.91520
# Epoch 201/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1436 - acc: 0.9968 - val_loss: 0.5400 - val_acc: 0.9144
#
# Epoch 00201: val_acc did not improve from 0.91520
# Epoch 202/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1432 - acc: 0.9971 - val_loss: 0.5403 - val_acc: 0.9141
#
# Epoch 00202: val_acc did not improve from 0.91520
# Epoch 203/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 70ms/step - loss: 0.1425 - acc: 0.9971 - val_loss: 0.5395 - val_acc: 0.9141
#
# Epoch 00203: val_acc did not improve from 0.91520
# Epoch 204/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 70ms/step - loss: 0.1443 - acc: 0.9964 - val_loss: 0.5399 - val_acc: 0.9142
#
# Epoch 00204: val_acc did not improve from 0.91520
# Epoch 205/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 70ms/step - loss: 0.1432 - acc: 0.9972 - val_loss: 0.5392 - val_acc: 0.9141
#
# Epoch 00205: val_acc did not improve from 0.91520
# Epoch 206/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 70ms/step - loss: 0.1428 - acc: 0.9971 - val_loss: 0.5389 - val_acc: 0.9140
#
# Epoch 00206: val_acc did not improve from 0.91520
# Epoch 207/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 70ms/step - loss: 0.1433 - acc: 0.9965 - val_loss: 0.5405 - val_acc: 0.9143
#
# Epoch 00207: val_acc did not improve from 0.91520
# Epoch 208/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1435 - acc: 0.9969 - val_loss: 0.5400 - val_acc: 0.9142
#
# Epoch 00208: val_acc did not improve from 0.91520
# Epoch 209/250
# Learning rate:  5e-07
# 391/391 [==============================] - 28s 71ms/step - loss: 0.1422 - acc: 0.9971 - val_loss: 0.5389 - val_acc: 0.9145
#
# Epoch 00209: val_acc did not improve from 0.91520
# Epoch 210/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 70ms/step - loss: 0.1434 - acc: 0.9969 - val_loss: 0.5406 - val_acc: 0.9138
#
# Epoch 00210: val_acc did not improve from 0.91520
# Epoch 211/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1436 - acc: 0.9964 - val_loss: 0.5394 - val_acc: 0.9140
#
# Epoch 00211: val_acc did not improve from 0.91520
# Epoch 212/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 70ms/step - loss: 0.1431 - acc: 0.9970 - val_loss: 0.5399 - val_acc: 0.9147
#
# Epoch 00212: val_acc did not improve from 0.91520
# Epoch 213/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1433 - acc: 0.9969 - val_loss: 0.5396 - val_acc: 0.9137
#
# Epoch 00213: val_acc did not improve from 0.91520
# Epoch 214/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1439 - acc: 0.9967 - val_loss: 0.5402 - val_acc: 0.9137
#
# Epoch 00214: val_acc did not improve from 0.91520
# Epoch 215/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 70ms/step - loss: 0.1421 - acc: 0.9977 - val_loss: 0.5410 - val_acc: 0.9145
#
# Epoch 00215: val_acc did not improve from 0.91520
# Epoch 216/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1433 - acc: 0.9971 - val_loss: 0.5394 - val_acc: 0.9148
#
# Epoch 00216: val_acc did not improve from 0.91520
# Epoch 217/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1433 - acc: 0.9971 - val_loss: 0.5400 - val_acc: 0.9144
#
# Epoch 00217: val_acc did not improve from 0.91520
# Epoch 218/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1438 - acc: 0.9966 - val_loss: 0.5393 - val_acc: 0.9143
#
# Epoch 00218: val_acc did not improve from 0.91520
# Epoch 219/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1432 - acc: 0.9969 - val_loss: 0.5396 - val_acc: 0.9133
#
# Epoch 00219: val_acc did not improve from 0.91520
# Epoch 220/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1435 - acc: 0.9969 - val_loss: 0.5405 - val_acc: 0.9138
#
# Epoch 00220: val_acc did not improve from 0.91520
# Epoch 221/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1420 - acc: 0.9977 - val_loss: 0.5387 - val_acc: 0.9144
#
# Epoch 00221: val_acc did not improve from 0.91520
# Epoch 222/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1426 - acc: 0.9975 - val_loss: 0.5393 - val_acc: 0.9142
#
# Epoch 00222: val_acc did not improve from 0.91520
# Epoch 223/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1435 - acc: 0.9969 - val_loss: 0.5400 - val_acc: 0.9140
#
# Epoch 00223: val_acc did not improve from 0.91520
# Epoch 224/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1428 - acc: 0.9977 - val_loss: 0.5410 - val_acc: 0.9143
#
# Epoch 00224: val_acc did not improve from 0.91520
# Epoch 225/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1439 - acc: 0.9969 - val_loss: 0.5413 - val_acc: 0.9136
#
# Epoch 00225: val_acc did not improve from 0.91520
# Epoch 226/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1426 - acc: 0.9976 - val_loss: 0.5405 - val_acc: 0.9138
#
# Epoch 00226: val_acc did not improve from 0.91520
# Epoch 227/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 70ms/step - loss: 0.1427 - acc: 0.9969 - val_loss: 0.5410 - val_acc: 0.9137
#
# Epoch 00227: val_acc did not improve from 0.91520
# Epoch 228/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1440 - acc: 0.9965 - val_loss: 0.5403 - val_acc: 0.9140
#
# Epoch 00228: val_acc did not improve from 0.91520
# Epoch 229/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1434 - acc: 0.9968 - val_loss: 0.5401 - val_acc: 0.9143
#
# Epoch 00229: val_acc did not improve from 0.91520
# Epoch 230/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1424 - acc: 0.9972 - val_loss: 0.5396 - val_acc: 0.9143
#
# Epoch 00230: val_acc did not improve from 0.91520
# Epoch 231/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1430 - acc: 0.9970 - val_loss: 0.5394 - val_acc: 0.9144
#
# Epoch 00231: val_acc did not improve from 0.91520
# Epoch 232/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 68ms/step - loss: 0.1429 - acc: 0.9971 - val_loss: 0.5405 - val_acc: 0.9136
#
# Epoch 00232: val_acc did not improve from 0.91520
# Epoch 233/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1418 - acc: 0.9972 - val_loss: 0.5412 - val_acc: 0.9141
#
# Epoch 00233: val_acc did not improve from 0.91520
# Epoch 234/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1429 - acc: 0.9972 - val_loss: 0.5406 - val_acc: 0.9134
#
# Epoch 00234: val_acc did not improve from 0.91520
# Epoch 235/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1427 - acc: 0.9969 - val_loss: 0.5423 - val_acc: 0.9138
#
# Epoch 00235: val_acc did not improve from 0.91520
# Epoch 236/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1429 - acc: 0.9973 - val_loss: 0.5409 - val_acc: 0.9138
#
# Epoch 00236: val_acc did not improve from 0.91520
# Epoch 237/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1424 - acc: 0.9972 - val_loss: 0.5408 - val_acc: 0.9138
#
# Epoch 00237: val_acc did not improve from 0.91520
# Epoch 238/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 70ms/step - loss: 0.1433 - acc: 0.9971 - val_loss: 0.5409 - val_acc: 0.9139
#
# Epoch 00238: val_acc did not improve from 0.91520
# Epoch 239/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1431 - acc: 0.9970 - val_loss: 0.5407 - val_acc: 0.9143
#
# Epoch 00239: val_acc did not improve from 0.91520
# Epoch 240/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1421 - acc: 0.9976 - val_loss: 0.5408 - val_acc: 0.9141
#
# Epoch 00240: val_acc did not improve from 0.91520
# Epoch 241/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1435 - acc: 0.9967 - val_loss: 0.5406 - val_acc: 0.9139
#
# Epoch 00241: val_acc did not improve from 0.91520
# Epoch 242/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1436 - acc: 0.9966 - val_loss: 0.5408 - val_acc: 0.9139
#
# Epoch 00242: val_acc did not improve from 0.91520
# Epoch 243/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 70ms/step - loss: 0.1421 - acc: 0.9973 - val_loss: 0.5401 - val_acc: 0.9140
#
# Epoch 00243: val_acc did not improve from 0.91520
# Epoch 244/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1424 - acc: 0.9971 - val_loss: 0.5408 - val_acc: 0.9140
#
# Epoch 00244: val_acc did not improve from 0.91520
# Epoch 245/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1431 - acc: 0.9973 - val_loss: 0.5396 - val_acc: 0.9135
#
# Epoch 00245: val_acc did not improve from 0.91520
# Epoch 246/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1424 - acc: 0.9975 - val_loss: 0.5409 - val_acc: 0.9137
#
# Epoch 00246: val_acc did not improve from 0.91520
# Epoch 247/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1427 - acc: 0.9970 - val_loss: 0.5409 - val_acc: 0.9128
#
# Epoch 00247: val_acc did not improve from 0.91520
# Epoch 248/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1426 - acc: 0.9972 - val_loss: 0.5408 - val_acc: 0.9132
#
# Epoch 00248: val_acc did not improve from 0.91520
# Epoch 249/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1435 - acc: 0.9967 - val_loss: 0.5401 - val_acc: 0.9132
#
# Epoch 00249: val_acc did not improve from 0.91520
# Epoch 250/250
# Learning rate:  5e-07
# 391/391 [==============================] - 27s 69ms/step - loss: 0.1436 - acc: 0.9968 - val_loss: 0.5420 - val_acc: 0.9139
#
# Epoch 00250: val_acc did not improve from 0.91520

# %%
import pickle

file_pi = open('trainHistoryDict', 'wb')
pickle.dump(history.history, file_pi)
file_pi.close()

# %%
history = pickle.load(open('trainHistoryDict', "rb"))

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(8, 8))
plt.grid(True)
plt.plot(history['loss'])
plt.plot(history['val_loss'])

# %%
plt.figure(figsize=(8, 8))
plt.grid(True)
plt.plot(1 - np.array(history['acc']))
plt.plot(1 - np.array(history['val_acc']))

# %%
def resnet_v1_with_svd_reg(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]
    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved
    (downsampled) by a convolutional layer with strides=2, while 
    the number of filters is doubled. Within each stage, 
    the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M
    Arguments:
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    Returns:
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, in [a])')
    # start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            # first layer but not first stack
            if stack > 0 and res_block == 0:  
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            # first layer but not first stack
            if stack > 0 and res_block == 0:
                # linear projection residual shortcut
                # connection to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
# score trained model
scores = model.evaluate(x_test,
                        y_test,
                        batch_size=batch_size,
                        verbose=0)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

# %%
from keras.applications.resnet50 import ResNet50
# create the base pre-trained model
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(pic_size, pic_size, 3))
